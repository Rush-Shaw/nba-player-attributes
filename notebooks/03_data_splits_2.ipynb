# %% [markdown]
# #### The Purpose of this Notebook is to Split the Data into Training, Validation and Testing Data

# %% [markdown]
# ##### Imports

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##### Directories and File Locations

# %%
BASE_DIR = Path.cwd().parent
RAW_DIR = BASE_DIR / "data" / "raw"
PROCESSED_DIR = BASE_DIR / "data" / "processed"
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# %%
df = pd.read_csv(PROCESSED_DIR / "nba_ml_dataset.csv")

# %% [markdown]
# ##### Training Split

# %%
train_df = df[df["season"].isin([2022, 2023, 2024])]

# %% [markdown]
# ##### Validation Split

# %%
# keeping this empty for now as we don't have enough data to create a validation set

# %% [markdown]
# ##### Testing Split

# %%
test_df = df[df["season"] == 2026]

# %% [markdown]
# ##### Save Completed Datasets

# %%
train_df.to_csv("../data/splits_2/train.csv", index=False)

# %%
#valid_df.to_csv("../data/splits_2/validation.csv", index=False)

# %%
test_df.to_csv("../data/splits_2/test.csv", index=False)
