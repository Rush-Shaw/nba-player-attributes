# %% [markdown]
# #### The Purpose of this Notebook is to Split the Data into Training, Validation and Testing Data

# %% [markdown]
# ##### Imports

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ##### Directories and File Locations

# %%
BASE_DIR = Path.cwd().parent
RAW_DIR = BASE_DIR / "data" / "raw"
PROCESSED_DIR = BASE_DIR / "data" / "processed"
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# %%
df = pd.read_csv(PROCESSED_DIR / "nba_ml_dataset.csv")

# %% [markdown]
# ##### Training Split

# %%
train_df = df[df["season"].isin([2022, 2023, 2024, 2026])]

# %% [markdown]
# ##### Save Completed Datasets

# %%
train_df.to_csv("../data/splits_3/train.csv", index=False)
